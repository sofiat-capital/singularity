# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib notebook

# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from alembic.autogenerate import compare_metadata

from alembic.migration import MigrationContext
from alembic.migration import MigrationContext
from alembic.autogenerate import compare_metadata
from sqlalchemy.schema import SchemaItem
from sqlalchemy.types import TypeEngine
from sqlalchemy import (create_engine, MetaData, Column,
        Integer, String, Table)
from sqlalchemy.orm import sessionmaker
import pprint
import pandas as pd

# %% [markdown]
# ## Initialize MasterAPI()

# %%
import MasterAPI
from interface import DataBaseAPI
from interface import BinanceAPI

# %%
api = MasterAPI.MasterAPI()
# Out:
# 2020-12-01 20:59:03 - MasterAPI: initializing MasterAPI
# 2020-12-01 20:59:03 - DataBaseAPI: initializing DataBaseAPI
# 2020-12-01 20:59:03 - SQLEngine: initializing SQL Engine
# 2020-12-01 20:59:03 - AnalyticsAPI: initializing AnalyticsAPI

# %%
#api.DataBaseAPI.DayCandle

DayCandle = api.DataBaseAPI.DayCandle
session = api.DataBaseAPI.engine.Session()

candles = session.query(DayCandle).filter(DayCandle.fk_idproduct_dayCandle == 4).all()

# %%
reformat = []
for candle in candles:
    
    reformat.append([candle.date, candle.close, candle.volume])

# %%
frame = pd.DataFrame(reformat, columns = ['date', 'close', 'volume'])

# %%
#frame.iloc[:,1].rolling(window=3).mean()

np.array(frame.iloc[:,1].rolling(window=3).mean()).shape
# Out:
# (1000,)

# %%
palette = cm.viridis

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 5))

ax.plot(frame['date'], frame['close'], color = 'black')
ax.plot(frame['date'], np.array(frame.iloc[:,1].rolling(window=30).mean()), label = '30 days')
ax.plot(frame['date'], np.array(frame.iloc[:,1].rolling(window=200).mean()), label = '200 days')


ax.set_ylabel("Price [$]")
ax.set_xlabel('Date')

ax.legend()

plt.savefig('ETH_MACD.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
'classes',
'close',
'date',
'fk_idproduct_dayCandle',
'hi',
'iddayCandle',
'low',
'metadata',
'numtrades',
'open',
'prepare',
'product',
'volume'
# Out:
# ['__abstract__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__mapper__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__table__',
#  '__weakref__',
#  '_decl_class_registry',
#  '_sa_class_manager',
#  '_sa_decl_prepare',
#  '_sa_raise_deferred_config',
#  'classes',
#  'close',
#  'date',
#  'fk_idproduct_dayCandle',
#  'hi',
#  'iddayCandle',
#  'low',
#  'metadata',
#  'numtrades',
#  'open',
#  'prepare',
#  'product',
#  'volume']

# %%
dir(candles[0])
# Out:
# ['__abstract__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__mapper__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__table__',
#  '__weakref__',
#  '_decl_class_registry',
#  '_sa_class_manager',
#  '_sa_decl_prepare',
#  '_sa_instance_state',
#  '_sa_raise_deferred_config',
#  'classes',
#  'close',
#  'date',
#  'fk_idproduct_dayCandle',
#  'hi',
#  'iddayCandle',
#  'low',
#  'metadata',
#  'numtrades',
#  'open',
#  'prepare',
#  'product',
#  'volume']
